# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/sima/git_projects/illumina-genotyping-pipeline/scripts/retrive_snp_gene/analysis_target_gene

# %%
df = pd.read_csv('target_gene_report.tsv', sep='\t')

# %%
df.shape
# Out:
# (29080, 294)

# %%
df.columns
# Out:
# Index(['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'UASG_1205',
#        ...
#        'UASG_0149', 'UASG_0258', 'UASG_0259', 'UASG_0304', 'UASG_0305',
#        'UASG_1099', 'UASG_1109', 'UASG_1141', 'UASG_1143', 'UASG_1178'],
#       dtype='object', length=294)

# %%
first_uasg = next(
    c for c in df.columns if 'UASG' in c
)
first_uasg
# Out:
# 'UASG_1205'

# %%
first_idx = df.columns.tolist().index(first_uasg)
first_idx
# Out:
# 9

# %%
uasg_lst = df.columns.tolist()[df.columns.get_loc(first_uasg):]

# %%
uasg_lst[:5]
# Out:
# ['UASG_1205', 'UASG_1206', 'UASG_1241', 'UASG_1244', 'UASG_1305']

# %%
df.columns[df.columns.get_loc('ID')]
# Out:
# 'ID'

# %%
/home/sima/git_projects/illumina-genotyping-pipeline/output/genotype_run1/target_lists/target_gene_report.tsv
